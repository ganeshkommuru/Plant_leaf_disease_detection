# %%
cpt=0
required_exxp = ['Peach___Bacterial_spot']#,'Peach___healthy']
for expression in required_exxp:
    for i in range(1,9):
        cpt += 1
        plt.subplot(8,8,cpt)
        img=load_img(train_path+expression+"\\"+os.listdir(train_path+expression)[i],target_size=(pic_size,pic_size))
        plt.imshow(img,cmap='gray')
        plt.xlabel(os.listdir(train_path+expression)[i])
#plt.tight_layout()
#plt.figure(0,figsize=(400,400))
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
train_path             = "C:\\Users\\ganesh appu\\Downloads\\project_imageprocessing\\Plant_leave_diseases_dataset_with_augmentation\\"

# %%
pic_size=256

# %%
from keras.preprocessing.image import load_img

# %%
import os

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
